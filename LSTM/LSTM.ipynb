# %% [markdown]
# # LSTM on Nietzche's Writings
#
# Example notebook to generate text from Nietzsche's writings. Adapted from this [Keras example](https://github.com/fchollet/keras/blob/master/examples/lstm_text_generation.py)
#
# At least 20 epochs are required before the generated text
# starts sounding coherent.
#
# It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
# Out:
# Using TensorFlow backend.

# %%
path = get_file('nietzsche.txt', origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt")
text = open(path).read().lower()
print('corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
#  16384/600901 [..............................] - ETA: 0scorpus length: 600901

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 59

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 200287

# %%
print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
# Out:
# Vectorization...
# Build model...

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y, batch_size=128, nb_epoch=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 200287/200287 [==============================] - 115s - loss: 1.9886
#
# ----- diversity: 0.2
# ----- Generating with seed: "of every nation given themselves!--not e"
# of every nation given themselves!--not even the conscience of the most and has the conscience of the prease and the conscience of the many in the conscience and the suppositity, and the conscience of a suppost the conscience of the conscience of the conscience of the propposent and supposition of supposite and the conscience of the propposs and many the canser and and the many the man and the sense the reaser and many and the suppositio
#
# ----- diversity: 0.5
# ----- Generating with seed: "of every nation given themselves!--not e"
# of every nation given themselves!--not even the for the poot and leveress, the conscience and suppreation and even and many the centence and an a sense cannes of ineverything the conscience of the
# constree and sentent the opposition for the
# conscience in the anderess, and shase and the may has he do word with the may relight the man as the love and conscience, and chrose and perhaps the
# sense supressible so this
# conscience and a suppost
#
# ----- diversity: 1.0
# ----- Generating with seed: "of every nation given themselves!--not e"
# of every nation given themselves!--not everythare langer antering of operation: only
# has beabits he unabwarden of which sirfleneld perutht and mary
# mary and the such resuctious have alromenf-with whoil, more has self-trous ofler sove, he psocess, everyther bast: he this wall saints many--there ourself in think everythings of the supprilatur? of the can rewholarl in eborits onlys weld have in well diffurs, here
# now in his
# now withly
# juat
#
# ----- diversity: 1.2
# ----- Generating with seed: "of every nation given themselves!--not e"
# of every nation given themselves!--not ever,
# neher?try ornant, which
# giom"--has
# shelryshys mangered, thines the
# cipce eusups. as in
# appeamss," in noxighrs" nound will simeon
# to
# seam be "scholofil (and feends ane dlseruless anot by" regrratm. therly
# phyopowraterhcubure, ares. may fay about" "the
# my caustab. resuncicifering-skething
# with wilches, his
# loke
# mit hosulst for the concomplos thosivh"
# vorenaliing, and "nughs" itself. he shablecc
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 200287/200287 [==============================] - 117s - loss: 1.6344
#
# ----- diversity: 0.2
# ----- Generating with seed: " in its destructive effect on the higher"
#  in its destructive effect on the higher and all the sensialis of the soul of the something and the entiments and all the or a still and an an only all the stranger be something the decience the something of the sensialis of the sensiality and the instinction of the sensialising and an all the him in the love of the sense of the believe of the sought of the sought of the life in the for the present and here in the sought of the sought o
#
# ----- diversity: 0.5
# ----- Generating with seed: " in its destructive effect on the higher"
#  in its destructive effect on the higher for who every instinct the of the very concerning that more the dow because of the not be nations, who leve nature, the which is the means of a solies the one can of the concerning, the nature, in the intentive of a grad the more of gontation of the him with as any the end and always and will not the sensiality of he "now not the whole resoluted and only the sensations, has more sensientes to the
#
# ----- diversity: 1.0
# ----- Generating with seed: " in its destructive effect on the higher"
#  in its destructive effect on the higher bolatical for that has redulcings, end
# moder mairvanhes honleral
# schorched which
# i not mense obliproun infleptise in ajoding has gowtre" not without tome of bad
# salction of express of the walliesed: with
# it soct of us of only domethes,
# more weaks (for commondian moray that mean for reterth, advation shall bast etage here
# humanives "there all gevents bowld; appeciousny
# in bould attence, not the bo
#
# ----- diversity: 1.2
# ----- Generating with seed: " in its destructive effect on the higher"
#  in its destructive effect on the higher have
# ghosps with ited, who no be day  lose inferethiraly invitionaly revicuful but instant for the resions anstfinincd ofiant; one cour--action, inking weaking perience, not propen in human eson, and art, natten, as ylost porcess artike for conceining. howe.=. uppettable not decience not
# from in alppicise do archatien and
# agistabel, will? evicialy in the stooval
# menhkinaly
# clead govers amanjiabe,
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 200287/200287 [==============================] - 118s - loss: 1.5430
#
# ----- diversity: 0.2
# ----- Generating with seed: "ecessors,
# we venture the following expos"
# ecessors,
# we venture the following expossion of the concerning the destracted the orders of the connection of the former to the contempative and the deverited to the present and the thing of the conscience of which it is the conscience of the whole the present the struck of the conscience of the contempativy and the present the conscience of the contrary the conscience of the present and in the schopenhary the complaily in the placed th
#
# ----- diversity: 0.5
# ----- Generating with seed: "ecessors,
# we venture the following expos"
# ecessors,
# we venture the following expossion of the generation is its sough to presence to a structed to not of man is human present of this is the contempatifical our possion and deceived the logiced the man has to the special, and the
# compassion is the sensuality in generally
# value, and all compatition as you shate also and the possible its who who is so man more as we
# struck of the fact, the confurual one our has a compassion of what
#
# ----- diversity: 1.0
# ----- Generating with seed: "ecessors,
# we venture the following expos"
# ecessors,
# we venture the following expossess, shoulds, protries. in hopaely artinussow one out our dangerous, there of mindwalk; and therefore of
# purtitious ene called soughibul "situality.
#
#
# 3a strudge,, and habits
# for the it to batity, and whether to indoining them with the are the ecigron to yet ofly deverate new lets to stapthed, but he from the be troubtly with or him in condition, to pleblem and nature, from the most proberity it
#
# ----- diversity: 1.2
# ----- Generating with seed: "ecessors,
# we venture the following expos"
# ecessors,
# we venture the following exposhy- of muxt; alfite. who been
# it conundate eye, _we soquiling the intation to plases cimmourally taste are to his "which betrewaly
# life.
#
#
# 111c=ytrait, and
# this operpratic contrir ourservativel; get -its ingook
# to it, he
# sates dowm, begabbe mangest moderm the all bishnte-my will we questions which the fundness who incompoger to rommant, thosted clui commanditipance with "idnotin
# cupily hard sucrve
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 200287/200287 [==============================] - 118s - loss: 1.4959
#
# ----- diversity: 0.2
# ----- Generating with seed: "n the evil,
# a certain dreadfulness, subt"
# n the evil,
# a certain dreadfulness, subtless and his power the sould and sentiment, the presust of the contempt of the historical and well of the same and the more of the same such and more and and all the so the same man is the sentiments of the same such and a sould the same such as the same man in the same such and so the sould and more of the same such as a sould and he has so the same souls and more of the same man well and some of
#
# ----- diversity: 0.5
# ----- Generating with seed: "n the evil,
# a certain dreadfulness, subt"
# n the evil,
# a certain dreadfulness, subtle, and belief in a strected to german the former the prevaise in religion to the under the intellectuality of the woman be belief to accourse and averation of the most it is a same for the more in the means of a shame to have in belief exercise and the least in all the goods and work in the superficy of such the deprection and
# more presurment of the conscience and sentiment or fully what he subse
#
# ----- diversity: 1.0
# ----- Generating with seed: "n the evil,
# a certain dreadfulness, subt"
# n the evil,
# a certain dreadfulness, subtless of faw of saless and them who have who know
# ; the
# dece become
# hoch of the say, was
# supamet, a courled to purciusts to be us to us.
# ! from the syus force, but good be termness of those would being deprecahation--and contacting a respire certate un estempticism; which we he is intoness of
# fenther merelible manres insist and natures. prevaive otic false to we a rimark manifes about
# thel, does e
#
# ----- diversity: 1.2
# ----- Generating with seed: "n the evil,
# a certain dreadfulness, subt"
# n the evil,
# a certain dreadfulness, subtuly.--in datt and imis histor, of nonge then pervess, condrious in must suem
# omaumor) for agis of ellow
# the.-"lict if we adms has nob-later wle. some. the)
# opiniss idxlitious
# free nature of suched--and alprowing
# is images in what can seas ou. perhaps unwerths ordinary whick nol, nay owing dove of keepo prevaited
# aver hivhorsicyrs
# has oth, that it "if moulthen to he rana-tront--who fee. quested req
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 200287/200287 [==============================] - 118s - loss: 1.4640
#
# ----- diversity: 0.2
# ----- Generating with seed: "something happens there as in the realm "
# something happens there as in the realm and the supersion of the and the prometic the supersion and the more of the origin in the more of the saint to the promited to the and and the intellect and the consequently and in the most and and the most the the more and to be will to the most the more and the sense, and the most and and and have and has the supersion of the more of the supersition of the all the origin in the more in the super
#
# ----- diversity: 0.5
# ----- Generating with seed: "something happens there as in the realm "
# something happens there as in the realm of many conscience and the promined to the emotion of the many the nature
# of this freed to all an asture that in the superior to himself is allowed bectad be motives in the point and all the indeent the "good "moral individual to all the most the supersition in the concepsism of consedving and and to the consequently and and confessed to the charch, than their more of the most religion to all the
#
# ----- diversity: 1.0
# ----- Generating with seed: "something happens there as in the realm "
# something happens there as in the realm to be agamantism musther for the concepthnce
# to knowledge. he can to hupred neived
# man is in lacking that many desire to it sould, in comroament or helply, not yet the history to the like, which for astariasificar century--far if no europe life not old guidence be such as to feally--
# . manifest
# first; about ankion
# "commonated, and
# who has origions as any wellory, and example things; it is a class
#
# ----- diversity: 1.2
# ----- Generating with seed: "something happens there as in the realm "
# something happens there as in the realm once a place will" as fore; to firms by exverie, whither of firithclax
# suspess to sty that all the first of it, iohieas, slure""s; as is nolly--upon "spirit"--which nobsses chorcepopjected
# coutars" its celted ! no sir,
# thus alnowions mogrins and human insisitation, to help.
#
# the sympoble
# sufferer, and
# men hencefort in any nededivonlying could diff curoar, cattemint
# myself.
# for
# words, orgrered
# thus
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 200287/200287 [==============================] - 118s - loss: 1.4432
#
# ----- diversity: 0.2
# ----- Generating with seed: " even a proper history of what has been "
#  even a proper history of what has been the conscience and standsportion of the conscience and and and more of the present and present and standards and an an interpress of the process and more of the process of the standards of the process of the extent of the standards of the present and and strang the present and in the conception of the still to the present of the mankind and standards of the experience, who would be a present and c
#
# ----- diversity: 0.5
# ----- Generating with seed: " even a proper history of what has been "
#  even a proper history of what has been domain to the powers of the does not belief that in
# compasite who has been a things and as the belong to the religious in the action with the conception of the suffering and still and sentiment and in artmantiman of a comparites of all the preservation with the standards of world to the work of methods of the
# entireabs and another as the powerful propution of ut a precisely the present and find fo
#
# ----- diversity: 1.0
# ----- Generating with seed: " even a proper history of what has been "
#  even a proper history of what has been mechorous philosophy; even a combully; indevelled. for instincting,
# at morals (there are possetied, gazed by the compler themowed henden, sfirar stiln obviously kpoly ingrater
# short. the materially mankind of life in
# philologive stand" as a
# deeded and viewerous int something his existioners, and in ideal, blosp. -human life which
# an it, chorsions, and not
# wethorous forst there clums to any "matuer
#
# ----- diversity: 1.2
# ----- Generating with seed: " even a proper history of what has been "
#  even a proper history of what has been acmastimanscent him. unyeal quite bone rely
# to oneks only christian obith europe would atter-a courceded, no pverson, very fait evicat of mysteine, promentler that it awnate".may nar whether on all the "progetfulness. -preallation: shourdivism of thinslly human, shed for begin
# to his na
# glory
# in surutuin simpance in back-:
# loos, is
# these while kferen conscience," at absecus respectly wincicavity,
#
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 200287/200287 [==============================] - 116s - loss: 1.4276
#
# ----- diversity: 0.2
# ----- Generating with seed: " them; indeed one might ask, as a physic"
#  them; indeed one might ask, as a physicult in the same the stronger to the stronger in the consequently the something in the stronger to the sense of the sense of the stronger to the same the subject of the soul of the stronger and the subject of the sense of the subject of the stronger to the sense is a subject of the stronger and stronger to the sense of the sense of the present that the subject of the sense and and a subject of the
#
# ----- diversity: 0.5
# ----- Generating with seed: " them; indeed one might ask, as a physic"
#  them; indeed one might ask, as a physicus certainly the consequently the free world to all the strene the power in the destine and connected and a speat in everything in the man of the more great we is a result and many called more things, that which is does it be
# not become subject, and without has a man the heart to a will of poterses of the consequences of the deated the more conceith to that which the such a sorring and
# as the thin
#
# ----- diversity: 1.0
# ----- Generating with seed: " them; indeed one might ask, as a physic"
#  them; indeed one might ask, as a physical whole manicul of
# how this begins,
# bad. resevaul
# need that is the world macife as -out of life themselves for a favour, that the innerequing recombaulred
# bettense in the busity,
# noble whockee is modence. the first, at the
# "liuhes lose oner that a chimancy! the poterwayly incossities who always such a spirits for romancegtion--assimul whends
# attensien of orderly allow--and consived of philosophy,
#
# ----- diversity: 1.2
# ----- Generating with seed: " them; indeed one might ask, as a physic"
#  them; indeed one might ask, as a physicus subjlctions, which character.
# the sleavt moralists.to
# be not not stays cannot the fad conscience is fineful, others creed smiley
# wronger--if however of life! that whaterorelishes is
# notthse"icys;
# i courses,
# the weaks.
#
# p6=tinic, ascection, that to fiscleny incoleof
# abtled".=--where that wotl to per,echand,", without, wypted of factly bandnoties dand!
# "gazrest punar, that a foresat dated byoruha
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 200287/200287 [==============================] - 113s - loss: 1.4150
#
# ----- diversity: 0.2
# ----- Generating with seed: "f the combatants may say: "either i
# cont"
# f the combatants may say: "either i
# contiman of the fact to the most disguised to the sees and probably now to the strange and so the sense of the any desirating and and and and and always something to the self-concealing and as the points and the strange of the strength of the strength of the spirit of the assestaing to the service to the acts and the fact to the acts and the present to the sense of the strength of the acts and the pre
#
# ----- diversity: 0.5
# ----- Generating with seed: "f the combatants may say: "either i
# cont"
# f the combatants may say: "either i
# contiman and of the
# sense: the estimate measant of the points without has seem of a now you little and the most well, and which all the errors, and discourage and more among the freedom of the most result in their own to be the delight of the virtues and century--and the results of all himself in the whole with the points of the more are believere at all approprigh to express of the serve to the most
#
# ----- diversity: 1.0
# ----- Generating with seed: "f the combatants may say: "either i
# cont"
# f the combatants may say: "either i
# contrasuscusity to in the world essential man added repeat seem in the people of suffered to thents divilint
# to a so blough "music of us. good motive man good and that the bedivary for the eternties of a same of necessative gener, perubtrs off to frencour--to corlusity witding, now be god philosophy endst science's har now diswiss, from invent of actside
# namely, some them-who has con, say, for they ar
#
# ----- diversity: 1.2
# ----- Generating with seed: "f the combatants may say: "either i
# cont"
# f the combatants may say: "either i
# contence as heard which the mase--afgethint ratasiaic on looking europeans, in the fongered quantang, any hesital beldive who ally be distincting
# for itself,  . unotion, which discredamenthess
# musip. in
# silenal, arey; on unbelity iccerthing hadmen'ing towards, their tyste, and hesitoonities havour science and danfe
# hablenesfy to haist, how oppresteold nowhanivouns which is pathers of roing modes optie
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 200287/200287 [==============================] - 113s - loss: 1.4043
#
# ----- diversity: 0.2
# ----- Generating with seed: "onstitution of these healthiest of
# all t"
# onstitution of these healthiest of
# all the same the sense, and the sense of the self concerning the soul of the soul of the conception of the struggle of the allow the sense of the struggle of the present and some singless of the ever of the sense of the the soul of the conception of the concerning of the most the sense of the sense, and the secret the soul of the concerning and the sense, the sense, the struggle of the soul of the sens
#
# ----- diversity: 0.5
# ----- Generating with seed: "onstitution of these healthiest of
# all t"
# onstitution of these healthiest of
# all the spirit of the great strugge and the soul for the mode, of all the valuation, the concerness of the most ever the the supersous of the morality and means of his destruction, and the former of our more
# soul
# in the most among the still him the evilable of an inner master,
# the present and intentional and many the strives and man, and in the understanding or all the respect
# experiences of the religi
#
# ----- diversity: 1.0
# ----- Generating with seed: "onstitution of these healthiest of
# all t"
# onstitution of these healthiest of
# all the view
# and a plais, after him, believe, there with soxicue for avow--that an oppear of
# interpreciation: such will-science.=--nuchers of our existence civilization, won irritreness is
# something us, as
# the cry, there
# thrs
# to centicore of relugant in the crabids, towards the reitraties. it is
# has there is atteuth--unmunh the traditions benothed yet, the
# conform and the errone--nathing the actsoxitie
#
# ----- diversity: 1.2
# ----- Generating with seed: "onstitution of these healthiest of
# all t"
# onstitution of these healthiest of
# all the highest a meterite on philoroph of hinass refred. while not to sather of these fien of everywer or knows of the pride, eved inlyjentish to manyly
# agacks and the dard
# by grante, over-ascatmers to apprecuatties.--fhatterable as
# the misuniest, preases.
# the
# soul: "even that showly unessowing reflically
# not why as
# so stien fool the lot
# accuratelafabaly; on a
# tigre. doubt the canstage. for the infere
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# 200287/200287 [==============================] - 113s - loss: 1.3962
#
# ----- diversity: 0.2
# ----- Generating with seed: "rror at once into the heart
# of the assai"
# rror at once into the heart
# of the assaive in the sales of the superior of the seem to the seems of the self-more sound the says and and the present in the present and the suffering and his own capacity of the present and an interpretation of the present and sought to the more and the world and the self-danger of the present and self-danger of the most distrust and souther the more in the conception of the seems of the says and form of
#
# ----- diversity: 0.5
# ----- Generating with seed: "rror at once into the heart
# of the assai"
# rror at once into the heart
# of the assaimers has not in the can more and sought the superiors of this general in the man who would not be advance of the strength, and such nature the fact of mind of an more must seem by the an intercane of all things and most intellectually in the work of an and an and the believed and man the souther of the ever to say. the and solitad in the present in the indigniars and into the present and his doctr
#
# ----- diversity: 1.0
# ----- Generating with seed: "rror at once into the heart
# of the assai"
# rror at once into the heart
# of the assaice, do a depression, self alto he was a great other however! but
# or thousan in the rsjolical especially
# states of reasen an, iver from the still into chorshe of unam. the oreein expression--let us render of it, but howevens the present and
# still
# ultimation, attempts it is whole testly, "to believe creator, at all for, that predecative something us, as the few, rangects it that it is intercrates pe
#
# ----- diversity: 1.2
# ----- Generating with seed: "rror at once into the heart
# of the assai"
# rror at once into the heart
# of the assaives withdies men have, trute with
# the expluosion
# and
# itsid and
# ancient- :
# and as inclince of
# nevert 'edition of mere-gentedable consequent and own part faice or incoldidists ideas, that is he will
# neaters in a
# toughtwmine
# bos-it is
# not    orck. which the
# backand merewher still acts rishold, unowings hangs, with no get temptds in a
# lick tahe:
# in thinkermity.
# we disdan
# purity": whith how in face civ
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# 200287/200287 [==============================] - 113s - loss: 1.3893
#
# ----- diversity: 0.2
# ----- Generating with seed: "
# sympathy, benevolence and sacrifice. bu"
#
# sympathy, benevolence and sacrifice. but the same the fact that the sense of the same the fact that is the senses the present and the super-to the present and impression of the present the present and the same the most the for the sort of the same the present and self to the most religion of the most the same the old the problem of the present and the same the sense of the same the same the old suffering and something the same the sens
#
# ----- diversity: 0.5
# ----- Generating with seed: "
# sympathy, benevolence and sacrifice. bu"
#
# sympathy, benevolence and sacrifice. but the emotions must be the sentiment at last the belief the stronger so because it is the perceive with the destiny, that the sake of the same that the fear of the ancient is the senses and present at the conceal, the concluse is the experiences of the present and the belief of imprecial experiences of all hole, at the problem that has many--and moral: if it is in the present in the less to an ext
#
# ----- diversity: 1.0
# ----- Generating with seed: "
# sympathy, benevolence and sacrifice. bu"
#
# sympathy, benevolence and sacrifice. but has so simult of our
# very
# sort of the ph make i in the un
#
# shach--as findrel of it.
#
#
# 105
#
# =bettre, not be organistes.
#
#
# 131
#
# =the scientifal and give their means of woman and most presents and advain is a moderne that implersive as at the future of word feeling the loved to hheur, a these delights which are freling in this was too
# experientic is not inatturelatively, that as it is certainres it
#
# ----- diversity: 1.2
# ----- Generating with seed: "
# sympathy, benevolence and sacrifice. bu"
#
# sympathy, benevolence and sacrifice. but he is to rease, a drideme. also trainking owe pearing exertion of deceived as madt those suvek of
# a soin out it betharveare--therefore to plaen, on, a centious, and with its peractant,--herefoolhwy. the destify; it is boston
# itseld,
# deferenting
# self covent aty, their very sonersous hubin
# skeptificall, as much is not
# etirufed to usal could ascecibed said, to thing eagination" its bodoully indulpr
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# 200287/200287 [==============================] - 114s - loss: 1.3812
#
# ----- diversity: 0.2
# ----- Generating with seed: "ple into the position
# of being obliged h"
# ple into the position
# of being obliged has been such and the contrary of the struggle of the sense of the present to the sense of the standpient of the struggles of the subject of the standpient of the strugglest the present to the present of the sense of the standpient of the struggless of the consequently the stands of the present to the present to the still to the presentement is the present in the still the concerned the subject of
#
# ----- diversity: 0.5
# ----- Generating with seed: "ple into the position
# of being obliged h"
# ple into the position
# of being obliged himself that the most preasure to this distance, is not the more profound and and the more intellectual and platony is a finally and continuation of his late that the belief the considers of the concern and the desire and subject of the world of characterism and desire to the mankind of its spectally and sciled and who is.
#
#
# 10eere of the sense of the highly the strugglest in the blain of the stand
#
# ----- diversity: 1.0
# ----- Generating with seed: "ple into the position
# of being obliged h"
# ple into the position
# of being obliged had instincties of an aression; in the
# world of
# beautifulligant to another to make it is real moral! we
# comrends."--wishing and teeproms and finalls only definite by his conduct, who
# argument we proportificated by anyond.
#
# 2
# oo hind, or, scientiviom of
# the conditions of virtue of time europe axisteds! diridian idea of conscience of
# "capable--they make hesition
# of
# the maither and instance in into th
#
# ----- diversity: 1.2
# ----- Generating with seed: "ple into the position
# of being obliged h"
# ple into the position
# of being obliged hard last power, nor, of
# toos"fience and questial c ; a "zicsiable
# po
# rairness of theceble-
# bust," withim of which we prrorening imbinize,
# belie break, on are spair ofight, mirdigem" her
# give some, myst delleking
# of whomh to will"
# bom
# sore fro
# everlus ofly of polituer, he he silection. chaugr.=--only above, the temos"opersflled age dif will atdioined at had, lative storms tobess perhaps,
# ih vareful
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/1
# 200287/200287 [==============================] - 114s - loss: 1.3772
#
# ----- diversity: 0.2
# ----- Generating with seed: "or a long time; otherwise thou wilt come"
# or a long time; otherwise thou wilt comes to the sense of the sense of the protection of the present and and and and the present and consequently and and former and the sense of the sense of the former to the sense, and we are the sense of the fact that it is a consequently and the southern of the sense of the present of the more soul and consequences and and the sense, and and the sense of the same themselves to the sense of the more p
#
# ----- diversity: 0.5
# ----- Generating with seed: "or a long time; otherwise thou wilt come"
# or a long time; otherwise thou wilt come to so the constrations of the
# hapters of the surpriss of the more
# good in the noration, and the reverences and nature of the sense to their actions as a soul of the heart of european in the presented to the served that not to the world to the
# entives as the nature of the world in the same man who are it is to problem of the fact to all the phosophers and and to the most dispains of the more commu
#
# ----- diversity: 1.0
# ----- Generating with seed: "or a long time; otherwise thou wilt come"
# or a long time; otherwise thou wilt comess belong for themselves of the
# discornized--insige there beaoning, of will that attection'ss
# science are nature. they greigorianderness, after, flative and his
# inderfly--toeptibsfulys and in spiest the tellence gothing of
# degree of the
# rooted therefore,
# seeplic languaged yet of some put truth. it is
# day
# by ethives mestanizations. the le ssquerous erron an alledly because the rayfured: against sen
#
# ----- diversity: 1.2
# ----- Generating with seed: "or a long time; otherwise thou wilt come"
# or a long time; otherwise thou wilt comestions), "ac at all suffers magilyd charm--
# :
#
#     now getious others on the
# despectionalies is tevenwariund
# gives he initiviok of gods or scient, seems a
# alto time our probably in the "seeping cry
# it will to kind
# on the act amout in its morality--and any asseration of was we; he were areful promblicauting--their future, for them, everyosent" self, to me, is tovent, almost life former alrealing wh
#
# --------------------------------------------------
# Iteration 14
# Epoch 1/1
# 200287/200287 [==============================] - 114s - loss: 1.3720
#
# ----- diversity: 0.2
# ----- Generating with seed: "ives access to
# the path of much and vari"
# ives access to
# the path of much and varied to the strength, and always believe that the strength of the also of the more of the subsequently the former the strength of such a strength of the sense of the subsequently and and in the master that the existed to the orderates the stronger the surmost of the experiences of the strength of the supermite of the strength of the stronger in the morality and the stronger the strongers of the mora
#
# ----- diversity: 0.5
# ----- Generating with seed: "ives access to
# the path of much and vari"
# ives access to
# the path of much and varied and had nothing and morality of the were of the conceal man is the for the masters be not man of whole interning the asking to the spirituality of the belief of a counted to distance, and for all the scientic presented the distance, when the most danger of his
# particus, the result and thread, in the fact the possible, in such a spirituality and who free, the words, and concerning sensus intelle
#
# ----- diversity: 1.0
# ----- Generating with seed: "ives access to
# the path of much and vari"
# ives access to
# the path of much and variety such
# oppositionrian obvoched flowers
# man lim letter, and evidswhare.
#
# 1aled and gratitud,
# the awarder insines inquire great those
# /home/icarus/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log
#  us, or who essentially scholimence than we
# indicatas moral interning ofse
# mount"
# conscience of tostering gerdene of
# man must bring
# his lore--for his creation. there are contemporar fundamentally
# alweed human. the
# tubinable imitacting in authority and perhaps if we a
#
# ----- diversity: 1.2
# ----- Generating with seed: "ives access to
# the path of much and vari"
# ives access to
# the path of much and variable posely in comparing more
# veryy.
#
#
# orestheric companisctation.
#
#
# 11ores orgerably so so, buroun inscood) our best go
# ste stilled
# to havy mankind
# and sigrabs, up! assold. the butted, of womperware unageness.ne's
# worsely contimation hadive chishien, to its sur"eptivity should that which we nor
# old
# bis : anys time has be will, and merely except of the strange,
# and
# "though brain,"
# to reached anipe
#
# --------------------------------------------------
# Iteration 15
# Epoch 1/1
# 200287/200287 [==============================] - 114s - loss: 1.3657
#
# ----- diversity: 0.2
# ----- Generating with seed: "effort or constraint, a "downwards" with"
# effort or constraint, a "downwards" with the sensations of the serve the struggle and the conception of the sense of the standsptages the deceived the superstition of the strung of the same the present to the sense of the world the self-man and more and the spirit. the sense of the most soul to the superstition with the served to the sense of the service of the sensations of the superior of the world and the conception of the sense of t
#
# ----- diversity: 0.5
# ----- Generating with seed: "effort or constraint, a "downwards" with"
# effort or constraint, a "downwards" with the process and salied to be the world of
# means of so that it was an avoids of claimes and to a conceile to a soul of which the present in the sense, and the prepudical lights, even and pain of century of his own religion the reads to be superstition of the problem and the service of the spirit respect of develops to the sensations, and thought a philosophers and deating end, the same that the co
#
# ----- diversity: 1.0
# ----- Generating with seed: "effort or constraint, a "downwards" with"
# effort or constraint, a "downwards" with mind of impossible soul to the levend tover to born world others ediration with the cotteotable
# car the peopla" ends doubked coors to nefore oppore? but at plotable
# conception. there exfecule, by the pease and forment as he first into the presentness,
# as thoughtevent and fines counched. there addical sagat,t--it may not thou places good beast man in such viciss," that drearn "pbeling of man and s
#
# ----- diversity: 1.2
# ----- Generating with seed: "effort or constraint, a "downwards" with"
# effort or constraint, a "downwards" with hindereat fform.fyor io here by is even with the bease reveine ares
# deger there--this philosopher,
# they are for worn not,
# of being frenchuous
# induicyso,ting the
# certainers-imparionating fulth such a skir, on to that keea, would first
# beyen" is
# his
# obclo--on the cigni" of like that that the suriexting; there." away his contrgurany besongual, too-
# who, tookon
# to order; one,
# the sin-in cluse say, he
#
# --------------------------------------------------
# Iteration 16
# Epoch 1/1
# 200287/200287 [==============================] - 114s - loss: 1.3614
#
# ----- diversity: 0.2
# ----- Generating with seed: " one's heart swell with pride. but we
# an"
#  one's heart swell with pride. but we
# and the sense of the superstiped to the subject. in the subject" which are something the subject" of the subject" of the consequent of the sense of the superstilition of the survival and the life the subject of the superstiped to the proportion to the subject. the subject of the subject have a subjection of the superstitious and the subject" of the subject" of the subject. in the proposition and the
#
# ----- diversity: 0.5
# ----- Generating with seed: " one's heart swell with pride. but we
# an"
#  one's heart swell with pride. but we
# and in the sufferer under the standard and surpres may want and atterpation in the general and in the souls of the enjoy the heart of the reado and strives for the self-contraderation of all such of the streas of the subject" of the power of the ever one is not to live which have development with the most
# difficult,
# and and love in the most dream-and the responsibility and even the such a power, and
#
# ----- diversity: 1.0
# ----- Generating with seed: " one's heart swell with pride. but we
# an"
#  one's heart swell with pride. but we
# and
# immense which silly,tp!
#
#
# 1ni
# (we were modal always emmbely out. one must presumptivity to ming measure of thereth a religions, are what ascete-dumbour foom taking sume no interpretation and ssciphifd-dgeens--necessary so do
# the sumratifing of tootle of spolit and him to say or estimate, of the loce, and everived" which certain itself. a probably themselves to it, as any period and cupacy in the
#
# ----- diversity: 1.2
# ----- Generating with seed: " one's heart swell with pride. but we
# an"
#  one's heart swell with pride. but we
# anyorour of hif. no "according thing,, people and colfurm has comporynanes
# religiousness and defective. the conception with
# instance
# an exist bud himhlet-lo!pjus aroldmenc. the abruct":--from goeted the life: so so sight
# figalticum of enrus after severeme--it is the musicial
# do
# that a rrouth have dabiling, family
# ticiage, that is a new modents whom a course of risgumes--in longing and play,s whom of
#
# --------------------------------------------------
# Iteration 17
# Epoch 1/1
# 200287/200287 [==============================] - 114s - loss: 1.3573
#
# ----- diversity: 0.2
# ----- Generating with seed: "hould like to express myself preliminari"
# hould like to express myself preliminaride is a subsolus of the selection of the selection and process and interpreterity and and the more of the man and the sense of the conscience, for the conscience of the most far that the sense of the strength of the old intellect and shame and interpreterity and subtlety, the conscience of the subtlety, and the conscience, the families of the man who is a subsolity of the strength of the made the
#
# ----- diversity: 0.5
# ----- Generating with seed: "hould like to express myself preliminari"
# hould like to express myself preliminarid and for have they be human process have the bloodies, of men be and the monowing and in all the man of which it is declise, if they is all this something the means which the property of the very made, the art himself the thing is in the same conscience, and has a spirits: even in the new
# ance of the experience of its virtue means is is not for world of the new labore of man of the power of exper
#
# ----- diversity: 1.0
# ----- Generating with seed: "hould like to express myself preliminari"
# hould like to express myself preliminarid apther of the gratified, yon ghowculal, dange.
# we have their tasteny for the "nationar to under the heohter which a virtue of falseles. he called imposed in
# their rnable
# with philosophers of self-investing. godcing
# afthen self-tiving, i
# otherd, the concealed humanint to the wand account eason to deceived
# richt--so that inte
# should in owird, and unhay
# an weanictor of gratitual notion of civilizat
#
# ----- diversity: 1.2
# ----- Generating with seed: "hould like to express myself preliminari"
# hould like to express myself preliminarid,
# hustial. more only givers sacrine, doverity, and moralisibility to petted curiosicorgics, the organizing, for the faither mechlators:
# being for the beautiby, they wiorl will no lugner tarturaul, on, haw pincests,
# supsoloom involvede in to to philosogical of counteds its condection
# (wertarily," egroshe sholsure herding, from med ambituation, but they to him, he cannerer togen did inanged, e, the
#
# --------------------------------------------------
# Iteration 18
# Epoch 1/1
# 200287/200287 [==============================] - 114s - loss: 1.3540
#
# ----- diversity: 0.2
# ----- Generating with seed: "ifficult to be understood, especially wh"
# ifficult to be understood, especially when it is the sense of the subserations of the the morality and the sense of the sense of the sublime and the sense of the sense of the soul. the same thing of the striving in the present the highest and the soul. the presence of the subsery of the subsery of the subserious and all the same things of the sense of the sense of the sense, and the problem of the soul, and the fact the presence of the
#
# ----- diversity: 0.5
# ----- Generating with seed: "ifficult to be understood, especially wh"
# ifficult to be understood, especially when they have the old prose. nompted he has is all the sense of the more philosophers the metaphoral life to his the word, of a subsome to the cause of the naturally in which it will the present man and far to all the sense of manifolitation of the same things the sense of prevail the enory and respect to all the long to the much as evil has been respect in its own strength of the actions existence
#
# ----- diversity: 1.0
# ----- Generating with seed: "ifficult to be understood, especially wh"
# ifficult to be understood, especially who
# the sain by
# goe imperce
# functions,
# a eurbentisciders have least sgriguinaue, of all, he platian fact at his, as sacrifices of credis" and philosopher
# experiences.
#
# loe and
# for dis, it spiritualism: i in light
# of the reason, like they will and persmagnionication of if by thies"-itpown tien has as more
# spechers--botbearious  : our read we has with the effect. the new closer, bosnes,
# but it is all
#
# ----- diversity: 1.2
# ----- Generating with seed: "ifficult to be understood, especially wh"
# ifficult to be understood, especially whereous showively no opposition" but cause in theow men, one should in i still fe, socrance reasoure!
# untewiariging!
#
# 239. yabsiseitales, just watcerited. he cannot say, when they meanes." centious, toolite without solem wethishous,
# his
# syntopriofoliass against vourdry
# efficuart to the bliod these.
#
# 2usible to
# conditionate science of the cause the eirpity--what bee
# divity, for but or "outlear-power
#
# --------------------------------------------------
# Iteration 19
# Epoch 1/1
# 200287/200287 [==============================] - 114s - loss: 1.3499
#
# ----- diversity: 0.2
# ----- Generating with seed: "e traditional defect in all philosophers"
# e traditional defect in all philosophers and the sensible to the properition of the statesmon of the properitive and the truth the same to the statesmon of the process the as the consequently the superiors of the statesmon of the conception of the contempt of the stated to the old same therefore, and as the formerly as the formerly all the process the stated to the properitive in the standard to the struggle the strive--and the french a
#
# ----- diversity: 0.5
# ----- Generating with seed: "e traditional defect in all philosophers"
# e traditional defect in all philosophers as a love to finness of the unman a sort of man is the respectance of approads of mingle the conception of the little all the organs the experiences and nothing the termost aspects in the astore thereby the stupidity and which profound to finaling by the moral being to a still to all the moral distrust to the sensation and always instinct because the moral of the other statesmon and acceding itse
#
# ----- diversity: 1.0
# ----- Generating with seed: "e traditional defect in all philosophers"
# e traditional defect in all philosophers from the spirituely has feitical? of such manifestness, assertibla told, this trort of the damgren of the pruders of glemgry's tooting thel. he predeard, authoride certain stand" and as all oness, of france masity for repain to the above all might giving intinsely first
# faith, at all corcum" ording are called evo offlinal of such
# of the back, and at the o. and which, volunt of the term, the creai
#
# ----- diversity: 1.2
# ----- Generating with seed: "e traditional defect in all philosophers"
# e traditional defect in all philosophers, a seorsis, there that nor repudaccry; seeking its
# fexiding
# ascribly mawnsoxites dogmets with theild
# injury a virtue
# of, hun
# so punish o my talem of ego," and psychology of things) applozing that it to"gin of so we would reventhing, preduraden the his
# power.
#
# irsted are
# suffreing immediate "sensual sumpationatity reschoriod; andt to the of
# step methods to the
# iblis of
# acgutatifly evenlyous so pla
#
# --------------------------------------------------
# Iteration 20
# Epoch 1/1
# 200287/200287 [==============================] - 114s - loss: 1.3466
#
# ----- diversity: 0.2
# ----- Generating with seed: "ry hand that lays hold of him shrinks ba"
# ry hand that lays hold of him shrinks bad, and the same to the same things and the subselled to the subselly and suffering and and to the stands and to complete of the subselled to him to the same things of the subtlety and the subserce of the same things and in the most a stands to the consequences and the same things and the most the same to the problem of the same to the reality and something to a subsele to the most the spiritual an
#
# ----- diversity: 0.5
# ----- Generating with seed: "ry hand that lays hold of him shrinks ba"
# ry hand that lays hold of him shrinks bad to be man is the sort
# of the other and can be the hearts as also a process is to which is the same and to the definitely appearance of the belief that the subaing in the self which it is even in the extraon--in the gained to stand to mine is remain last man and to give often all the conception of the exacting the entirely and the severity in the case of the and among the processes
# and the strang
#
# ----- diversity: 1.0
# ----- Generating with seed: "ry hand that lays hold of him shrinks ba"
# ry hand that lays hold of him shrinks bad, ever away prooty. the highest for this
# morality, and
# will; and a woman itself, or are co to co teptions power of this principary begins; to himself his own man finally is suspicion of the
# glextung; but sees aarible to gestably, platoid to astife
# double by us. upleaborroual faires present and his espis 'endi-cotty: we buss, and and must bad a secret so. generally as the didient wand to feeling m
#
# ----- diversity: 1.2
# ----- Generating with seed: "ry hand that lays hold of him shrinks ba"
# ry hand that lays hold of him shrinks batupreneranized and de. order, deep. doing; they wishes to
# sumbermed heartgsefor-educhest temsty the troudeds, would like couraivesul wild to ssjay le, species; avoided and when setticallfativhivenal evetesmics do to falslsion comitofly
# musout so immenses over, aronggn time-estion, and not embldi that resultus: that
# called peoples
# of means
# of [in the statliccounly
# opposibility, so the pearys" upage
#
# --------------------------------------------------
# Iteration 21
# Epoch 1/1
# 100608/200287 [==============>...............] - ETA: 56s - loss: 1.3299
